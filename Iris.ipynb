# %%
import pandas as pd
import numpy as np
import seaborn as sb

# %%
df = pd.read_csv("Iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
# Distplot shows the overall distribution of continuous data
sb.set_style('whitegrid')
sb.distplot(df['PetalLengthCm'],color ='red', kde=False)
# Out:
# <AxesSubplot:xlabel='PetalLengthCm'>

# %%
sb.histplot(df['PetalWidthCm'],kde=True, bins=5, fill=False, stat='probability')  # kde = kernel density estimate(It is a curve line over graph)
# Out:
# <AxesSubplot:xlabel='PetalWidthCm', ylabel='Probability'>

# %%
sb.set_style('ticks')
sb.distplot(df['PetalLengthCm'])
# Out:
# C:\Users\panka\AppData\Roaming\Python\Python39\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='Density'>

# %%
#Displays default color palette.
sb.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
# Scatter plot is plot with the dots.
sb.scatterplot(x= df['PetalWidthCm'], y=df['Species'], palette='terrain')
# Out:
# <AxesSubplot:xlabel='PetalWidthCm', ylabel='Species'>

# %%
sb.lineplot(x='SepalLengthCm', y='SepalWidthCm', data=df, color='blue')
#  OR
# sb.lineplot(x=df['SepalLengthCm'], y=df['SepalWidthCm'], color='blue')
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
sb.set_style('white')
sb.FacetGrid(df)

# %%
g= sb.FacetGrid(df, col='Species')
g.map(sb.histplot, "PetalLengthCm", color='blue')

# %%
g= sb.FacetGrid(df, col='Species')
g.map_dataframe(sb.histplot, y="PetalLengthCm", color='blue')

# %%
type(g)
# Out:
# seaborn.axisgrid.FacetGrid

# %%
sb.scatterplot(data=df, x="PetalLengthCm", y="PetalWidthCm", color='yellow')
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %%
sb.barplot(x='PetalWidthCm', y='PetalLengthCm', data=df)
# Out:
# <AxesSubplot:xlabel='PetalWidthCm', ylabel='PetalLengthCm'>

# %%
sb.countplot(x ='Species', data = df, palette='Pastel1')
# Out:
# <AxesSubplot:xlabel='Species', ylabel='count'>

# %%
sb.boxplot(x = 'PetalLengthCm', y = 'Species', data = df)
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='Species'>

# %%
sb.violinplot(x ="PetalLengthCm", y="Species", data = df)
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='Species'>

# %%
#stripplot
sb.stripplot(x="PetalLengthCm", y="Species", data=df)
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='Species'>

# %%
#swarmplot
sb.swarmplot(x="PetalLengthCm", y="Species", data=df)
# Out:
# C:\Users\panka\AppData\Roaming\Python\Python39\site-packages\seaborn\categorical.py:1296: UserWarning: 8.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='Species'>

# %%
import warnings
warnings.filterwarnings('ignore')

#kdeplot
sb.kdeplot(df['PetalLengthCm'],df['SepalWidthCm'],color='blue',cbar=True)
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='SepalWidthCm'>

# %%
#pairplot
sb.pairplot(df, hue ='Species',size=4)
